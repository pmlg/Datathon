# %%
from PIL import Image, ImageFilter
import os
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# %%
img_f = '3.tif'
image=Image.open(img_f); image
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGBA size=583x582 at 0x149D9727448>

# %% [markdown]
# ### Image Properties

# %%
print(image.size)
print(image.format)
print(image.mode)
# Out:
# (583, 582)
# TIFF
# RGBA

# %% [markdown]
# ### Red Channel

# %%
# Method to process the red band
def pixelProcRed(intensity):
    return intensity

# Method to process the blue band
def pixelProcBlue(intensity):
    return 0

# Method to process the green band
def pixelProcGreen(intensity):
    return 0

# Create an image object
imageObject = Image.open(img_f)

# Split the red, green and blue bands from the Image
multiBands  = imageObject.split()

# Apply point operations that does thresholding on each color band
redBand      = multiBands[0].point(pixelProcRed)
greenBand    = multiBands[1].point(pixelProcGreen)
blueBand     = multiBands[2].point(pixelProcBlue)

# Display the individual band after thresholding
redBand
# Out:
# <PIL.Image.Image image mode=L size=583x582 at 0x149D6432DC8>

# %%
# Create a new image from the thresholded red, green and blue brands
newImage = Image.merge("RGB", (redBand, greenBand, blueBand))

# Display the merged image after thresholding
newImage
# Out:
# <PIL.Image.Image image mode=RGB size=583x582 at 0x149D972E408>

# %%
rb2arr = np.array(redBand)
rb2arr.max()
# Out:
# 0

# %% [markdown]
# #### Green Channel

# %%
# Method to process the red band
def pixelProcRed(intensity):
    return 0

# Method to process the blue band
def pixelProcBlue(intensity):
    return 0

# Method to process the green band
def pixelProcGreen(intensity):
    return intensity

# Create an image object
imageObject = Image.open(img_f)

# Split the red, green and blue bands from the Image
multiBands  = imageObject.split()

# Apply point operations that does thresholding on each color band
redBand      = multiBands[0].point(pixelProcRed)
greenBand    = multiBands[1].point(pixelProcGreen)
blueBand     = multiBands[2].point(pixelProcBlue)

# Display the individual band after thresholding
greenBand
# Out:
# <PIL.Image.Image image mode=L size=583x582 at 0x149D9717E08>

# %%
# Create a new image from the thresholded red, green and blue brands
newImage = Image.merge("RGB", (redBand, greenBand, blueBand))

# Display the merged image after thresholding
newImage
# Out:
# <PIL.Image.Image image mode=RGB size=583x582 at 0x149D973B3C8>

# %% [markdown]
# ### Blue Channel

# %%
# Method to process the red band
def pixelProcRed(intensity):
    return 0

# Method to process the blue band
def pixelProcBlue(intensity):
    return intensity

# Method to process the green band
def pixelProcGreen(intensity):
    return 0

# Create an image object
imageObject = Image.open(img_f)

# Split the red, green and blue bands from the Image
multiBands  = imageObject.split()

# Apply point operations that does thresholding on each color band
redBand      = multiBands[0].point(pixelProcRed)
greenBand    = multiBands[1].point(pixelProcGreen)
blueBand     = multiBands[2].point(pixelProcBlue)

# Display the individual band after thresholding
blueBand
# Out:
# <PIL.Image.Image image mode=L size=583x582 at 0x149D64334C8>

# %%
# Create a new image from the thresholded red, green and blue brands
newImage = Image.merge("RGB", (redBand, greenBand, blueBand))

# Display the merged image after thresholding
newImage
# Out:
# <PIL.Image.Image image mode=RGB size=583x582 at 0x149D9730788>

# %%
newImage.save('3_b.png')

# %% [markdown]
# ### Edge Detection

# %%
# Create an image object
image = greenBand

# Find the edges by applying the filter ImageFilter.FIND_EDGES
imageWithEdges = image.filter(ImageFilter.FIND_EDGES)
imageWithEdges
# Out:
# <PIL.Image.Image image mode=L size=583x582 at 0x149D9730CC8>

# %%
# Create an image object
image = blueBand

# Find the edges by applying the filter ImageFilter.FIND_EDGES
imageWithEdges = image.filter(ImageFilter.FIND_EDGES)
imageWithEdges
# Out:
# <PIL.Image.Image image mode=L size=583x582 at 0x149D973B808>
